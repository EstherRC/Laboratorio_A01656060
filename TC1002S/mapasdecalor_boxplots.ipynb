# %% [markdown]
# <img src="https://maestriasydiplomadostec.blob.core.windows.net/maestriasydiplomados/uploads/escuela_posgrado/logo/6/ingenieria.jpg" alt="HTML5" style="width:500px;height:100px">
#
# # **Herramientas computacionales: el arte de la analítica**
# # Actividad Evaluable: Mapas de calor y boxplots
#
#
# *Grupo:* TC1002S.115
#
# *Liga Canvas:* https://experiencia21.tec.mx/courses/405474/
#
#
# *Alumno*
# <ul>
#   <li>Román Mauricio Elias Valencia - <a href="mailto:a01656603@tec.mx">a01656603@tec.mx</a></li>
#   <li>María Esther Ramírez Cedillo - <a href="mailto:a01656060@tec.mx">a01656060@tec.mx</a></li>
#   <li>David González Alanis - <a href="mailto:a016@tec.mx">a016@tec.mx</a></li>
# </ul>
#
# *Profesor*
# <ul>
#   <li>José Ángel Martínez Navarro - <a href="mailto:josekun13@tec.mx">josekun13@tec.mx</a></li>
# </ul>

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('/content/sample_data/covid19_tweets.csv')

sns.boxplot(x=df['user_followers'])
plt.title('Diagrama de Caja y Bigotes para user_followers')
plt.show()

sns.boxplot(x=df['user_favourites'])
plt.title('Diagrama de Caja y Bigotes para user_favourites')
plt.show()

sns.boxplot(x=df['user_friends'])
plt.title('Diagrama de Caja y Bigotes para user_friends')
plt.show()

# %%
df['user_created'] = pd.to_datetime(df['user_created'])

df_filtered = df[df['user_created'].dt.year > 2000]

plt.hist(df_filtered['user_created'].dt.year, bins=20)
plt.title('Histograma para Verificar año de creación (Después de 2000)')
plt.xlabel('Año de creación')
plt.ylabel('Frecuencia')
plt.show()

# %%
numeric_columns = df.select_dtypes(include=['number'])

corr_matrix = numeric_columns.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Mapa de Calor de Correlación')
plt.show()

# %% [markdown]
# #Preguntas
#
# 1.   ¿Hay alguna variable que no aporta información?
#
# Consideramos que la variable user_description, no aporta nada de valor al igual que user verified. De igual manera el nombre del usuario y el contenido del tweet resultan irrelevantes en la mayor parte de la analítica
#
# 2.   Si tuvieras que eliminar variables, ¿cuáles quitarías y por qué?
#
# user_description = Es muy vaga y podría contener una infinidad de expresiones,  por lo que no es utilizable en la analítica.
# user_verification = No tiene relevancia con el resto de los datos, únicamente se podría relacionar con los seguidores, pero no es un aspecto que busquemos analizar
#
# 3.   ¿Existen variables que tengan datos extraños?
#
# Todos las variables que no son valores númericos o booleanos cuentan con  datos extraños debido a la libertad que le es otorgada a los usuarios de twitter. No mantienen ningún formato especifico, a excepción de la fecha, por lo que genera irregularidades y redundancia al analizar esos datos
#
# 4.   Si comparas las variables, ¿todas están en rangos similares? ¿Crees que esto afecte?
#
# Comparando las variables númericas únicamente y utilizando el diagrama de caja y bigotes, podemos notar como se encuentran en rangos muy similares. Hay mucha densidad en los números bajos y poco a poco comienzan a distanciarse conforme aumenta la variable, ya sea de seguidores, amigos o favoritos.
#
# 5.   ¿Puedes encontrar grupos qué se parezcan? ¿Qué grupos son estos?
# todos los númericos se parecen, son los siguientes: user_followers, user_ favourites y user_friends.
# Estos grupos podemos notar que tienen un crecimiento similar, pero a la hora de analizarlo de forma más exahustiva, podemos notar que no existe una correlación entre estos datos.
